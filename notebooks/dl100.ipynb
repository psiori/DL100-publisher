# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
# %matplotlib inline

# %%
from dl100_client import Dl100Client

# %%
dl100 = Dl100Client(host="192.168.100.236", port=44818)

# %%
dl100.record_data(period=1/30)

# %%
dl100.df.plot(subplots=True, figsize=(20,10));

# %%
dl100.df.tail()
# Out:
#                             distance  velocity
# 2020-02-04 15:38:51.716660    3531.0       7.0
# 2020-02-04 15:38:51.752417    3531.0      -3.0
# 2020-02-04 15:38:51.787418    3530.0     -10.0
# 2020-02-04 15:38:51.827703    3530.0     -19.0
# 2020-02-04 15:38:51.868889    3531.0      28.0
